# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report,confusion_matrix
from sklearn import tree , datasets
import os

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# data source path
data_path = r'./data'
final_data_path = r'./final_data'

# %%
# data read and rename columns 
birth_col = ['cow_number','confinement date','Date of dried milk','calf number1','calf number2','cow weight','login date'
            ,'Calculated tire','tire','difficulty level of confinement','calf size','calf gender','farm number']

report_col = ['ID','year','month','farm number','cow_number','father_cow_number','mother_cow_number','birthday','tire'
              ,'lactation date','milk support','last confinement date','sampling date','age of month','inspection date'
             ,'final breeding date','final breeding semen','breeding times','before confinement date','first breeding date'
             ,'first breeding semen']

birth_df = pd.read_csv(os.path.join(data_path , 'birth.csv') , names = birth_col,  skiprows=1)
report_df = pd.read_csv(os.path.join(data_path , 'report.csv') , names = report_col , skiprows=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(report_col)
# Out:
# 21

# %%
print('birth table : ')
print ("Dataset Shape:: ", birth_df.shape)
birth_df.head()
# Out:
# birth table :
# Dataset Shape::  (3761, 13)
#    cow_number confinement date Date of dried milk calf number1 calf number2  \
# 0    87121677   2013/1/4 00:00                NaN          NaN          NaN
# 1    96126940   2013/1/2 00:00                NaN          NaN          NaN
# 2    95181708  2013/1/14 00:00     2014/1/3 00:00      2188113          NaN
# 3    97127665   2013/1/9 00:00    2014/3/12 00:00          NaN          NaN
# 4    97182634   2013/1/9 00:00    2014/3/25 00:00          NaN          NaN
#
#    cow weight       login date  Calculated tire  tire  \
# 0         NaN  2013/1/25 00:00             True     2
# 1       522.0  2013/1/25 00:00             True     2
# 2       670.0  2013/1/25 00:00             True     5
# 3         NaN  2013/1/25 00:00             True     3
# 4       630.0  2013/1/25 00:00             True     4
#
#    difficulty level of confinement calf size calf gender farm number
# 0                              1.0       NaN         NaN           B
# 1                              2.0       NaN         NaN           B
# 2                              1.0       NaN         NaN           C
# 3                              2.0       NaN         NaN           B
# 4                              1.0       NaN         NaN           C

# %%
print('report table : ')
print ("Dataset Shape:: ", report_df.shape)
report_df.head()
# Out:
# report table :
# Dataset Shape::  (37517, 21)
#    ID  year  month farm number  cow_number father_cow_number  \
# 0   1  2013      3           A       52612          507H7173
# 1   2  2013      4           A       52612          507H7173
# 2   3  2013      5           A       52612          507H7173
# 3   4  2013      6           A       52612          507H7173
# 4   5  2013      7           A       52612          507H7173
#
#   mother_cow_number        birthday  tire  lactation date  \
# 0          96040545  2011/1/1 00:00     1            78.0
# 1          96040545  2011/1/1 00:00     1           107.0
# 2          96040545  2011/1/1 00:00     1           140.0
# 3          96040545  2011/1/1 00:00     1           175.0
# 4          96040545  2011/1/1 00:00     1           210.0
#
#           ...           last confinement date    sampling date age of month  \
# 0         ...                  2013/1/1 00:00  2013/3/20 00:00           26
# 1         ...                  2013/1/1 00:00  2013/4/18 00:00           27
# 2         ...                  2013/1/1 00:00  2013/5/21 00:00           28
# 3         ...                  2013/1/1 00:00  2013/6/25 00:00           29
# 4         ...                  2013/1/1 00:00  2013/7/30 00:00           30
#
#    inspection date final breeding date final breeding semen breeding times  \
# 0  2013/3/21 00:00      2015/5/5 00:00            507H11621              1
# 1  2013/4/19 00:00      2015/5/5 00:00            507H11621              1
# 2  2013/5/22 00:00      2015/5/5 00:00            507H11621              2
# 3  2013/6/26 00:00      2015/5/5 00:00            507H11621              2
# 4  2013/7/31 00:00      2015/5/5 00:00            507H11621              2
#
#    before confinement date first breeding date first breeding semen
# 0                      NaN      2013/3/5 00:00             501H8784
# 1                      NaN      2013/3/5 00:00             501H8784
# 2                      NaN      2013/3/5 00:00             501H8784
# 3                      NaN      2013/3/5 00:00             501H8784
# 4                      NaN      2013/3/5 00:00             501H8784
#
# [5 rows x 21 columns]

# %%
# change string to int 

def replace_string_int(x , items):
    for i,j in items:
        if x == j :
            return str(i) 

def change_col(col_list,report_df):
    for col in col_list:
        farm_number_list = list(set(report_df[col]))
        turple_fram_number = [i for i in enumerate(farm_number_list)]
        #print(turple_fram_number)
        report_df[col] = report_df[col].apply(lambda x : replace_string_int(x , turple_fram_number))
        
    return report_df
    
change_col_list = ['farm number','final breeding semen','first breeding semen','father_cow_number','mother_cow_number']
report_df = change_col(change_col_list , report_df)

# %%
temp_df = report_df.drop(['birthday','lactation date','last confinement date','sampling date','inspection date'
                   ,'final breeding date','before confinement date','first breeding date'],axis=1)
temp_df = temp_df.dropna()
x = temp_df.drop('milk support',axis=1)
y = temp_df['milk support']

x_train, x_test, y_train, y_test = train_test_split( x, y, test_size = 0.2, random_state = 100)
print('x train shape {}'.format(x_train.shape))
print('x test shape {}'.format(x_test.shape))
print('y train shape {}'.format(y_train.shape))
print('y test shape {}'.format(y_test.shape))
# Out:
# x train shape (23229, 12)
# x test shape (5808, 12)
# y train shape (23229,)
# y test shape (5808,)

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error as mse
reg = linear_model.LinearRegression()
reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

print('Linear Regression with MSE is {} score'.format(mse(y_pred ,y_test)))
# Out:
# Linear Regression with MSE is 49.78137813735281 score

# %%
# Bayesian Ridge Regression

reg = linear_model.BayesianRidge()
reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)
print('Bayesian Ridge Regression with MSE is {} score'.format(mse(y_pred ,y_test)))
# Out:
# Bayesian Ridge Regression with MSE is 49.78117337558755 score

# %%
# Polynomial + linear model using pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
model = Pipeline([('poly', PolynomialFeatures(degree=5)),
                   ('linear', linear_model.LinearRegression(fit_intercept=False))])
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print('Polynomial degree=3 + linear model using pipeline with MSE is {} score'.format(mse(y_pred ,y_test)))

# %%
# Support Vector Machines
from sklearn import svm

model = svm.SVR()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
print('Support Vector Machines Regression with MSE is {} score'.format(mse(y_pred ,y_test)))
# Out:
# Support Vector Machines Regression with MSE is 63.699397388933335 score

# %%
# Stochastic Gradient Descent Regression

model = linear_model.SGDRegressor(max_iter=1000, tol=1e-4)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
print('Stochastic Gradient Descent Regression with MSE is {} score'.format(mse(y_pred ,y_test)))
# Out:
# Stochastic Gradient Descent Regression with MSE is 1.3317516509357144e+48 score

# %%
# Decision Tree Regression
from sklearn import tree
model = tree.DecisionTreeRegressor()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
print('Decision Tree Regression  with MSE is {} score'.format(mse(y_pred ,y_test)))
# Out:
# Decision Tree Regression  with MSE is 48.391272382920114 score

# %%
# Decision Tree Regression + Bagging Regressor
from sklearn import tree
from sklearn.ensemble import BaggingRegressor

model = BaggingRegressor(tree.DecisionTreeRegressor())
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
print('Bagging Regressor + Decision Tree Regression  with MSE is {} score'.format(mse(y_pred ,y_test)))
# Out:
# Bagging Regressor + Decision Tree Regression  with MSE is 28.964170007575763 score

# %%
# RandomForestRegressor
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(max_depth=2, random_state=0)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
print('RandomForestRegressor  with MSE is {} score'.format(mse(y_pred ,y_test)))
# Out:
# RandomForestRegressor  with MSE is 55.523034504685384 score

# %%
# DecisionTreeRegressor + AdaBoostRegressor
from sklearn import tree
from sklearn.ensemble import AdaBoostRegressor

model = AdaBoostRegressor(tree.DecisionTreeRegressor(max_depth=4),n_estimators=1000, random_state=np.random.RandomState(1))
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
print('DecisionTreeRegressor + AdaBoostRegressor  with MSE is {} score'.format(mse(y_pred ,y_test)))
# Out:
# DecisionTreeRegressor + AdaBoostRegressor  with MSE is 48.998283776377114 score

# %%
# GradientBoostingRegressor GBDT
from sklearn import tree
from sklearn.ensemble import GradientBoostingRegressor

model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=1, random_state=0, loss='ls')
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
print('GradientBoostingRegressor  with MSE is {} score'.format(mse(y_pred ,y_test)))
# Out:
# GradientBoostingRegressor  with MSE is 49.677858791053445 score

# %%
# Voting Regressor
from sklearn import tree
from sklearn.ensemble import VotingRegressor

model = VotingRegressor(estimators=[('gb', reg1), ('rf', reg2), ('lr', reg3)])
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
print('Voting Regressor  with MSE is {} score'.format(mse(y_pred ,y_test)))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-54-2ad5885ef9ac> in <module>()
#       1 # Voting Regressor
#       2 from sklearn import tree
# ----> 3 from sklearn.ensemble import VotingRegressor
#       4
#       5 model = VotingRegressor(estimators=[('gb', reg1), ('rf', reg2), ('lr', reg3)])
#
# ImportError: cannot import name 'VotingRegressor'

# %%
# StackingRegressor
from sklearn import tree
from sklearn.ensemble import GradientBoostingRegressor , StackingRegressor ,RandomForestRegressor
from sklearn.svm import SVR

estimators = [('ridge', linear_model.RidgeCV()),
             ('lasso', linear_model.LassoCV(random_state=42)),
              ('svr', SVR(C=1, gamma=1e-6))]
final_layer = StackingRegressor(estimators=[('rf', RandomForestRegressor(random_state=42)),
                ('gbrt', GradientBoostingRegressor(random_state=42))],final_estimator=RidgeCV())


multi_layer_regressor  = StackingRegressor(estimators=estimators , final_estimators = final_layer)
multi_layer_regressor.fit(x_train,y_train)
y_pred = model.predict(x_test)
print('Voting Regressor  with MSE is {} score'.format(mse(y_pred ,y_test)))
# Out:
# [autoreload of sklearn.utils.random failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 384, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 323, in update_generic
#     update(a, b)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: random_choice_csc() requires a code object with 0 free vars, not 2
# ]
# [autoreload of sklearn.neighbors.regression failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\regression.py", line 4, in <module>
#     from . import _regression
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_regression.py", line 17, in <module>
#     from ._base import _get_weights, _check_weights, NeighborsBase, KNeighborsMixin
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 23, in <module>
#     from ..base import BaseEstimator, MultiOutputMixin
# ImportError: cannot import name 'MultiOutputMixin'
# ]
# [autoreload of sklearn.feature_extraction failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\__init__.py", line 8, in <module>
#     from ._hashing import FeatureHasher
# ImportError: cannot import name 'FeatureHasher'
# ]
# [autoreload of sklearn.datasets.olivetti_faces failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\datasets\olivetti_faces.py", line 6, in <module>
#     from ..utils.deprecation import _raise_dep_warning_if_not_pytest
# ImportError: cannot import name '_raise_dep_warning_if_not_pytest'
# ]
# [autoreload of sklearn.datasets.rcv1 failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\datasets\rcv1.py", line 4, in <module>
#     from . import _rcv1
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\datasets\_rcv1.py", line 26, in <module>
#     from ._svmlight_format import load_svmlight_files
# ImportError: cannot import name 'load_svmlight_files'
# ]
# [autoreload of sklearn.linear_model.sag failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\sag.py", line 4, in <module>
#     from . import _sag
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_sag.py", line 11, in <module>
#     from ._base import make_dataset
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 27, in <module>
#     from ..base import (BaseEstimator, ClassifierMixin, RegressorMixin,
# ImportError: cannot import name 'MultiOutputMixin'
# ]
# [autoreload of sklearn.datasets.samples_generator failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\datasets\samples_generator.py", line 6, in <module>
#     from ..utils.deprecation import _raise_dep_warning_if_not_pytest
# ImportError: cannot import name '_raise_dep_warning_if_not_pytest'
# ]
# [autoreload of sklearn.metrics.classification failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py", line 6, in <module>
#     from ..utils.deprecation import _raise_dep_warning_if_not_pytest
# ImportError: cannot import name '_raise_dep_warning_if_not_pytest'
# ]
# [autoreload of sklearn.metrics.cluster failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\cluster\__init__.py", line 8, in <module>
#     from ._supervised import adjusted_mutual_info_score
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py", line 25, in <module>
#     from ...utils.fixes import comb, _astype_copy_false
# ImportError: cannot import name '_astype_copy_false'
# ]
# [autoreload of sklearn.linear_model.theil_sen failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\theil_sen.py", line 4, in <module>
#     from . import _theil_sen
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_theil_sen.py", line 20, in <module>
#     from ._base import LinearModel
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 27, in <module>
#     from ..base import (BaseEstimator, ClassifierMixin, RegressorMixin,
# ImportError: cannot import name 'MultiOutputMixin'
# ]
# [autoreload of sklearn.neighbors.base failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\base.py", line 4, in <module>
#     from . import _base
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 23, in <module>
#     from ..base import BaseEstimator, MultiOutputMixin
# ImportError: cannot import name 'MultiOutputMixin'
# ]
# [autoreload of sklearn.utils failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\__init__.py", line 26, in <module>
#     from .validation import (as_float_array,
# ImportError: cannot import name 'check_scalar'
# ]
# [autoreload of sklearn.model_selection._search failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py", line 38, in <module>
#     from ..metrics._scorer import _check_multimetric_scoring
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 28, in <module>
#     from . import (r2_score, median_absolute_error, max_error, mean_absolute_error,
# ImportError: cannot import name 'max_error'
# ]
# [autoreload of sklearn.feature_selection.rfe failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\rfe.py", line 4, in <module>
#     from . import _rfe
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\_rfe.py", line 22, in <module>
#     from ..metrics import check_scoring
# ImportError: cannot import name 'check_scoring'
# ]
# [autoreload of sklearn.linear_model.omp failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\omp.py", line 4, in <module>
#     from . import _omp
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_omp.py", line 16, in <module>
#     from ._base import LinearModel, _pre_fit
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 27, in <module>
#     from ..base import (BaseEstimator, ClassifierMixin, RegressorMixin,
# ImportError: cannot import name 'MultiOutputMixin'
# ]
# [autoreload of sklearn.tree failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\__init__.py", line 6, in <module>
#     from ._classes import BaseDecisionTree
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 31, in <module>
#     from ..base import MultiOutputMixin
# ImportError: cannot import name 'MultiOutputMixin'
# ]
# [autoreload of sklearn.linear_model.base failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\base.py", line 4, in <module>
#     from . import _base
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 27, in <module>
#     from ..base import (BaseEstimator, ClassifierMixin, RegressorMixin,
# ImportError: cannot import name 'MultiOutputMixin'
# ]
# [autoreload of sklearn.linear_model.huber failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\huber.py", line 4, in <module>
#     from . import _huber
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_huber.py", line 9, in <module>
#     from ._base import LinearModel
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 27, in <module>
#     from ..base import (BaseEstimator, ClassifierMixin, RegressorMixin,
# ImportError: cannot import name 'MultiOutputMixin'
# ]
# [autoreload of sklearn.model_selection._split failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py", line 22, in <module>
#     from ..utils import indexable, check_random_state, _safe_indexing
# ImportError: cannot import name '_safe_indexing'
# ]
# [autoreload of sklearn.linear_model.coordinate_descent failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py", line 4, in <module>
#     from . import _coordinate_descent
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 16, in <module>
#     from ._base import LinearModel, _pre_fit
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 27, in <module>
#     from ..base import (BaseEstimator, ClassifierMixin, RegressorMixin,
# ImportError: cannot import name 'MultiOutputMixin'
# ]
# [autoreload of sklearn.metrics.cluster.supervised failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\cluster\supervised.py", line 4, in <module>
#     from . import _supervised
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py", line 25, in <module>
#     from ...utils.fixes import comb, _astype_copy_false
# ImportError: cannot import name '_astype_copy_false'
# ]
# [autoreload of sklearn.utils.validation failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py", line 24, in <module>
#     from .fixes import _object_dtype_isnan
# ImportError: cannot import name '_object_dtype_isnan'
# ]
# [autoreload of sklearn.model_selection._validation failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 24, in <module>
#     from ..utils import (indexable, check_random_state, _safe_indexing,
# ImportError: cannot import name '_safe_indexing'
# ]
# [autoreload of sklearn.pipeline failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 22, in <module>
#     from .utils import Bunch, _print_elapsed_time
# ImportError: cannot import name '_print_elapsed_time'
# ]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# [autoreload of sklearn.datasets.kddcup99 failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\datasets\kddcup99.py", line 6, in <module>
#     from ..utils.deprecation import _raise_dep_warning_if_not_pytest
# ImportError: cannot import name '_raise_dep_warning_if_not_pytest'
# ]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# [autoreload of sklearn.externals.six failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 384, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 323, in update_generic
#     update(a, b)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 275, in update_class
#     old_obj = getattr(old, key)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\externals\six.py", line 87, in __get__
# AttributeError: 'NoneType' object has no attribute 'tkinter_commondialog'
# ]
# [autoreload of sklearn.neighbors.lof failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\lof.py", line 4, in <module>
#     from . import _lof
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_lof.py", line 8, in <module>
#     from ._base import NeighborsBase
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 23, in <module>
#     from ..base import BaseEstimator, MultiOutputMixin
# ImportError: cannot import name 'MultiOutputMixin'
# ]
# [autoreload of sklearn.linear_model.stochastic_gradient failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py", line 4, in <module>
#     from . import _stochastic_gradient
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py", line 15, in <module>
#     from ._base import LinearClassifierMixin, SparseCoefMixin
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 27, in <module>
#     from ..base import (BaseEstimator, ClassifierMixin, RegressorMixin,
# ImportError: cannot import name 'MultiOutputMixin'
# ]
# [autoreload of sklearn.feature_selection failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\__init__.py", line 20, in <module>
#     from ._rfe import RFE
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\_rfe.py", line 22, in <module>
#     from ..metrics import check_scoring
# ImportError: cannot import name 'check_scoring'
# ]
# [autoreload of sklearn.linear_model.least_angle failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py", line 4, in <module>
#     from . import _least_angle
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py", line 20, in <module>
#     from ._base import LinearModel
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 27, in <module>
#     from ..base import (BaseEstimator, ClassifierMixin, RegressorMixin,
# ImportError: cannot import name 'MultiOutputMixin'
# ]
# [autoreload of sklearn.ensemble.iforest failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py", line 4, in <module>
#     from . import _iforest
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_iforest.py", line 11, in <module>
#     from ..utils import (
# ImportError: cannot import name 'get_chunk_n_rows'
# ]
# [autoreload of sklearn.feature_selection.variance_threshold failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\variance_threshold.py", line 6, in <module>
#     from ..utils.deprecation import _raise_dep_warning_if_not_pytest
# ImportError: cannot import name '_raise_dep_warning_if_not_pytest'
# ]
# [autoreload of sklearn.metrics.regression failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\regression.py", line 6, in <module>
#     from ..utils.deprecation import _raise_dep_warning_if_not_pytest
# ImportError: cannot import name '_raise_dep_warning_if_not_pytest'
# ]
# [autoreload of sklearn.linear_model.perceptron failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\perceptron.py", line 4, in <module>
#     from . import _perceptron
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_perceptron.py", line 4, in <module>
#     from ._stochastic_gradient import BaseSGDClassifier
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py", line 15, in <module>
#     from ._base import LinearClassifierMixin, SparseCoefMixin
# ImportError: cannot import name 'MultiOutputMixin'
# ]
# [autoreload of sklearn.ensemble.partial_dependence failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\partial_dependence.py", line 23, in <module>
#     from ._gb import BaseGradientBoosting
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 50, in <module>
#     from . import _gb_losses
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_gb_losses.py", line 14, in <module>
#     from ..dummy import DummyClassifier
# ImportError: cannot import name 'MultiOutputMixin'
# ]
# [autoreload of sklearn.random_projection failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 384, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 323, in update_generic
#     update(a, b)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: sparse_random_matrix() requires a code object with 0 free vars, not 2
# ]
# [autoreload of sklearn.ensemble.weight_boosting failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py", line 4, in <module>
#     from . import _weight_boosting
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py", line 36, in <module>
#     from ..utils import check_array, check_random_state, check_X_y, _safe_indexing
# ImportError: cannot import name '_safe_indexing'
# ]
# [autoreload of sklearn.feature_extraction.stop_words failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\stop_words.py", line 6, in <module>
#     from ..utils.deprecation import _raise_dep_warning_if_not_pytest
# ImportError: cannot import name '_raise_dep_warning_if_not_pytest'
# ]
# [autoreload of sklearn.linear_model.bayes failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\bayes.py", line 4, in <module>
#     from . import _bayes
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_bayes.py", line 12, in <module>
#     from ._base import LinearModel, _rescale_data
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py", line 27, in <module>
#     from ..base import (BaseEstimator, ClassifierMixin, RegressorMixin,
# ImportError: cannot import name 'MultiOutputMixin'
# ]
# [autoreload of sklearn.utils.optimize failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 384, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 323, in update_generic
#     update(a, b)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: newton_cg() requires a code object with 0 free vars, not 2
# ]
# [autoreload of sklearn.ensemble.bagging failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\bagging.py", line 4, in <module>
#     from . import _bagging
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_bagging.py", line 24, in <module>
#     from ..utils.validation import has_fit_parameter, check_is_fitted, \
# ImportError: cannot import name '_check_sample_weight'
# ]
# [autoreload of sklearn.preprocessing failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\__init__.py", line 8, in <module>
#     from ._data import Binarizer
# ...
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\base.py", line 6, in <module>
#     from ..utils.deprecation import _raise_dep_warning_if_not_pytest
# ImportError: cannot import name '_raise_dep_warning_if_not_pytest'
# ]
# [autoreload of sklearn.feature_selection.univariate_selection failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\univariate_selection.py", line 6, in <module>
#     from ..utils.deprecation import _raise_dep_warning_if_not_pytest
# ImportError: cannot import name '_raise_dep_warning_if_not_pytest'
# ]
# [autoreload of sklearn.ensemble.base failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\base.py", line 6, in <module>
#     from ..utils.deprecation import _raise_dep_warning_if_not_pytest
# ImportError: cannot import name '_raise_dep_warning_if_not_pytest'
# ]
# [autoreload of sklearn.metrics.cluster.bicluster failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\cluster\bicluster.py", line 6, in <module>
#     from ...utils.deprecation import _raise_dep_warning_if_not_pytest
# ImportError: cannot import name '_raise_dep_warning_if_not_pytest'
# ]
# [autoreload of sklearn.neighbors.graph failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\graph.py", line 4, in <module>
#     from . import _graph
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_graph.py", line 7, in <module>
#     from ._base import KNeighborsMixin, RadiusNeighborsMixin
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 23, in <module>
#     from ..base import BaseEstimator, MultiOutputMixin
# ImportError: cannot import name 'MultiOutputMixin'
# ]
# [autoreload of sklearn.neighbors failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\__init__.py", line 9, in <module>
#     from ._graph import kneighbors_graph, radius_neighbors_graph
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_graph.py", line 7, in <module>
#     from ._base import KNeighborsMixin, RadiusNeighborsMixin
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 23, in <module>
#     from ..base import BaseEstimator, MultiOutputMixin
# ImportError: cannot import name 'MultiOutputMixin'
# ]
# [autoreload of sklearn.ensemble.gradient_boosting failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\gradient_boosting.py", line 4, in <module>
#     from . import _gb
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py", line 50, in <module>
#     from . import _gb_losses
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_gb_losses.py", line 14, in <module>
#     from ..dummy import DummyClassifier
# ImportError: cannot import name 'MultiOutputMixin'
# ]
# [autoreload of sklearn.metrics.pairwise failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py", line 26, in <module>
#     from ..utils import gen_batches, get_chunk_n_rows
# ImportError: cannot import name 'get_chunk_n_rows'
# ]
# [autoreload of sklearn.feature_extraction.hashing failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\hashing.py", line 6, in <module>
#     from ..utils.deprecation import _raise_dep_warning_if_not_pytest
# ImportError: cannot import name '_raise_dep_warning_if_not_pytest'
# ]
# [autoreload of sklearn.metrics.scorer failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\scorer.py", line 4, in <module>
#     from . import _scorer
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 28, in <module>
#     from . import (r2_score, median_absolute_error, max_error, mean_absolute_error,
# ImportError: cannot import name 'max_error'
# ]
# [autoreload of sklearn.datasets.base failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\datasets\base.py", line 6, in <module>
#     from ..utils.deprecation import _raise_dep_warning_if_not_pytest
# ImportError: cannot import name '_raise_dep_warning_if_not_pytest'
# ]
# [autoreload of sklearn.svm.bounds failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\bounds.py", line 6, in <module>
#     from ..utils.deprecation import _raise_dep_warning_if_not_pytest
# ImportError: cannot import name '_raise_dep_warning_if_not_pytest'
# ]
# [autoreload of sklearn.utils.metaestimators failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\metaestimators.py", line 11, in <module>
#     from ..utils import _safe_indexing
# ImportError: cannot import name '_safe_indexing'
# ]
# [autoreload of sklearn.datasets.svmlight_format failed: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 697, in exec_module
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\datasets\svmlight_format.py", line 6, in <module>
#     from ..utils.deprecation import _raise_dep_warning_if_not_pytest
# ImportError: cannot import name '_raise_dep_warning_if_not_pytest'
# ]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.metrics.ranking module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-55-4988418469bb> in <module>()
#       1 # Voting Regressor
#       2 from sklearn import tree
# ----> 3 from sklearn.ensemble import VotingRegressor
#       4 from sklearn.svm import SVR
#       5 estimators = [('ridge', linear_model.RidgeCV()),
#
# ImportError: cannot import name 'VotingRegressor'
